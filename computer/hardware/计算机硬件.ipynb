# %% [markdown]
# # 计算机硬件
#
# ## $\S0$ CPU
# cpu是主要影响矩阵运算效率的模块。
#
# ### $\S0.0$ 核心数
#
# 每个核心管理若干线程（也就1,2,3个）。
#
# ### $\S0.1$ 线程数
#
# 可计算的并行任务的数量。一般卖电脑的会写总数。一个核心是多少还要自己算。
#
# 举例：2个核心，三个线程。其中一个核心使用了超线程技术，因此可以同时处理2个线程，而另一个核心只处理1个线程。
#
# ### $\S0.2$ 频率
#
# 单程任务的计算速度，理论上这个最考验技术。
#
# ### $\S0.3$ 相关产品。
#
# 1. AMD EPYC 霄龙，并行计算强
# 2. intel ，单程计算强，打游戏用的。。。
